# %% [markdown]
# <a href="https://colab.research.google.com/github/MV2290/Google-Maps-Scrape/blob/main/Google_translator_italian_cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !pip install googletrans==3.1.0a0

# %%
# import libraries
import googletrans
from googletrans import Translator
import pandas as pd

# %% [markdown]
# # Import data

# %%
#Retrive world cities list
data = pd.read_excel('/content/drive/MyDrive/worldcities.xlsx')
italian_cities = data[data['country'] == 'Italy']

# %% [markdown]
# # Translate

# %%
translator = Translator()
def translation(word):
  t_word = translator.translate(word, src='en', dest='it')
  return t_word.text

# %%
italian_cities['city_ita'] = italian_cities['city'].apply(translation)
italian_cities['region_ita'] = italian_cities['admin_name'].apply(translation)
italian_cities
# Out:
# <ipython-input-23-bc73d9b10b77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italian_cities['city_ita'] = italian_cities['city'].apply(translation)
# <ipython-input-23-bc73d9b10b77>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italian_cities['region_ita'] = italian_cities['admin_name'].apply(translation)
#              city  city_ascii      lat      lng country iso2 iso3  admin_name  \
# 281          Rome        Rome  41.8931  12.4828   Italy   IT  ITA       Lazio
# ...

# %%
ita_city = italian_cities[['city_ita','region_ita']].copy()
ita_city
# Out:
#          city_ita  region_ita
# 281          Roma       Lazio
# 563        Milano   Lombardia
# 929        Napoli     Campano
# 1003       Torino    Piemonte
# 1232      Palermo     Sicilia
# ...           ...         ...
# 43456      Ittiri    Sardegna
# 43478  Ferrandina  Basilicata
# 43481   Calvisano   Lombardia
# 43491       Cagli      Marche
# 44213      Cabras    Sardegna
#
# [1363 rows x 2 columns]

# %% [markdown]
# # Check

# %%
# Check unique values
unique = ita_city['region_ita'].unique()
unique

# %%
# Manually correct bad translations if needed
original_words = ['Campano','veneto']
replace_words = ['Campania','Veneto']
column_to_replace = 'region_ita'

for index,word in enumerate(original_words):
  ita_city[column_to_replace] = ita_city[column_to_replace].replace(word,replace_words[index])

ita_city
# Out:
#          city_ita  region_ita
# 281          Roma       Lazio
# 563        Milano   Lombardia
# 929        Napoli    Campania
# 1003       Torino    Piemonte
# 1232      Palermo     Sicilia
# ...           ...         ...
# 43456      Ittiri    Sardegna
# 43478  Ferrandina  Basilicata
# 43481   Calvisano   Lombardia
# 43491       Cagli      Marche
# 44213      Cabras    Sardegna
#
# [1363 rows x 2 columns]

# %% [markdown]
# # Export

# %%
excel_file_path = '/content/drive/MyDrive/ItalianCities.xlsx'
ita_city.to_excel(excel_file_path,'Italian cities and regions')
print(f"DataFrame has been exported to {excel_file_path}")
# Out:
# DataFrame has been exported to /content/drive/MyDrive/ItalianCities.xlsx
